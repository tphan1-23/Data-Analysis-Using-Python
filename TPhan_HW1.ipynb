# %% [markdown]
# # **Homework 1 - Python Basics**
#
# Programmer name: Thanh Phan
#
# #### **A python program that calculate board-feet - a standard unit used to measure lumber volume, using Python variables, constants, operators, a list, and built-in functions, and it will perform the calculations and display clearly formatted results on the screen.**

# %% [markdown]
# ## **Academic Integrity Statement**
#
# By submitting this code for grading, I confirm the following:
#
# - that this is Notebook represents my own unique code created as a solution to the assigned problem.
# - that this is Notebook was created specifically to satisfy the requirements detailed in this assignment.
#
# Other than the textbook and material presented during our class sessions, I received help in designing and bebugging my code from the following people and/or websites:
#
# 1. None

# %%
#Species of wood
species = "cherry"

#cost per board in dollars
wood_cost_per_board = 5.80

#dimensions of the board in inches
length = 48
width = 3
thickness = 1

#sales tax rate
SALES_TAX_RATE = 0.09 

#message to customer
MESSAGE = "...THANK YOU!"

#custormer's order in board feet
customers = ['Nigel Incubator-Jones', 'Oliver St John-Mollusc','Gervaise Brook-Hampster','Simon Zinc-Trumpet-Harris']

purchase_customer = customers[2]

#calculate the total board feet of the order
total_board_feet = (length * width * thickness) / 144

#calculate the total cost of the order
total_wood_price = total_board_feet * wood_cost_per_board

#calculate the sales tax amount
sales_tax = total_wood_price * SALES_TAX_RATE

#calculate sales tax on grand total 
grand_total = total_wood_price + sales_tax

print("Customer name: ", purchase_customer, MESSAGE, 
      "\nWood species: ", species, 
      "\nTotal board-feet: ", total_board_feet, 
      "\nPrice for wood: ", total_wood_price, 
      "\nSales tax: ", sales_tax, 
      "\nTotal due: ", grand_total)
# Out:
# Customer name:  Gervaise Brook-Hampster ...THANK YOU!
# Wood species:  cherry
# Total board-feet:  1.0
# Price for wood:  5.8
# Sales tax:  0.522
# Total due:  6.322
